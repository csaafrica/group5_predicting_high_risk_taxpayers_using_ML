# %% [markdown]
# ## Business Understanding

# %% [markdown]
# ### Overview
# Tax authorities often struggle to efficiently identify taxpayers who pose compliance risks, resulting in revenue leakage and ineffective audit targeting. With limited resources, it's essential to prioritize audits based on risk levels. This project leverages historical taxpayer data to build a machine learning model that classifies taxpayers into High, Medium, or Low Risk categories. The insights generated can support smarter enforcement, better resource allocation, and improved tax compliance outcomes.

# %% [markdown]
# ### Business Problem
# Tax authorities need a reliable way to identify and prioritize risky taxpayers for audits and enforcement.
# This project seeks to develop a predictive model that uses taxpayer data to classify risk levels and enable more targeted, efficient compliance actions.
#
# To address this, we aim to:
# - Predict taxpayers who pose a high compliance risk.
# - Identify industries that are more prone to non-compliance.
# - rovide actionable insights to audit teams for targeted enforcement decisions.

# %% [markdown]
# ## Data Understanding
# The dataset being used for this project was obtained from kaggle. Here, we are going to review the dataset to assess the structure and characteristics of the data.

# %%
#importing necessary liblaries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder, OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, roc_auc_score, roc_curve
#from imblearn.over_sampling import SMOTE

# %%
#loading our data, that is in csv format
imported_data = pd.read_csv("../data/tax_risk_dataset.csv")

# %%
#make a copy of the original data
data=imported_data.copy()

# %%
# displaying the first five rows of our data
data.head()
# Out:
#    Taxpayer_ID     Revenue   Expenses  Tax_Liability  Tax_Paid  Late_Filings  \
# 0            1  1149014.25  979871.09       39872.33  28921.92             2
# 1            2   958520.71  884926.74       47832.22  39396.15             1
# 2            3  1194306.56  711926.07       38113.70  43863.94             4
# 3            4  1456908.96  570612.64       45380.58  66876.88             4
# 4            5   929753.99  839644.66       21595.78  53565.53             0
#
#    Compliance_Violations       Industry     Profit  Tax_Compliance_Ratio  \
# 0                      1        Finance  169143.16                  0.73
# 1                      1         Retail   73593.97                  0.82
# 2                      0  Manufacturing  482380.49                  1.15
# 3                      2        Finance  886296.32                  1.47
# 4                      0           Tech   90109.33                  2.48
#
#    Audit_Findings  Audit_to_Tax_Ratio Risk_Label
# 0               0                 0.0       High
# 1               0                 0.0     Medium
# 2               3                 0.0       High
# 3               1                 0.0       High
# 4               2                 0.0        Low

# %%
# displaying the las 5 records of our data
data.tail()
# Out:
#      Taxpayer_ID     Revenue   Expenses  Tax_Liability  Tax_Paid  \
# 995          996   915669.91  914030.05       51162.21  48284.58
# 996          997  1539305.96  694695.75       53866.29  27221.88
# 997          998  1192252.86  523625.07       31373.59  44797.02
# 998          999   828646.30  667386.61       55012.65  64433.78
# 999         1000  1171774.83  551019.47       47671.11  51606.48
#
#      Late_Filings  Compliance_Violations Industry     Profit  \
# 995             2                      2  Finance    1639.86
# 996             1                      0   Retail  844610.21
# 997             2                      1   Retail  668627.79
# 998             4                      0     Tech  161259.69
# 999             3                      2     Tech  620755.36
#
#      Tax_Compliance_Ratio  Audit_Findings  Audit_to_Tax_Ratio Risk_Label
# 995                  0.94               3                 0.0       High
# 996                  0.51               9                 0.0       High
# 997                  1.43               0                 0.0     Medium
# 998                  1.17               3                 0.0       High
# 999                  1.08               9                 0.0       High

# %%
#knowing the number of rows and columns
data.shape
# Out:
# (1000, 13)

# %% [markdown]
# The data has 1000 rows and 13 columns.

# %%
# Get general information on the data and each column.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Taxpayer_ID            1000 non-null   int64
#  1   Revenue                1000 non-null   float64
#  2   Expenses               1000 non-null   float64
#  3   Tax_Liability          1000 non-null   float64
#  4   Tax_Paid               1000 non-null   float64
#  5   Late_Filings           1000 non-null   int64
#  6   Compliance_Violations  1000 non-null   int64
#  7   Industry               1000 non-null   object
#  8   Profit                 1000 non-null   float64
#  9   Tax_Compliance_Ratio   1000 non-null   float64
#  10  Audit_Findings         1000 non-null   int64
#  11  Audit_to_Tax_Ratio     1000 non-null   float64
#  12  Risk_Label             1000 non-null   object
# dtypes: float64(7), int64(4), object(2)
# memory usage: 101.7+ KB

# %% [markdown]
# We have found out that:
# - 4 columns are of integer datatype.
# - 7 columns are of datatype float.
# - There are 2 columns with object datatype.

# %%
#get the summary statistics of the columns that contain numerical data.
data.describe()
# Out:
#        Taxpayer_ID       Revenue      Expenses  Tax_Liability      Tax_Paid  \
# count  1000.000000  1.000000e+03  1.000000e+03    1000.000000   1000.000000
# mean    500.500000  1.005800e+06  7.141672e+05   50087.513200  47812.807910
# std     288.819436  2.937648e+05  1.994909e+05   14751.814482  10271.325437
# min       1.000000  2.761980e+04  1.119223e+05    4707.320000  18705.510000
# 25%     250.750000  8.057229e+05  5.787517e+05   40280.002500  40625.797500
# 50%     500.500000  1.007590e+06  7.126154e+05   49996.240000  48001.845000
# 75%     750.250000  1.194383e+06  8.457764e+05   59913.732500  54669.455000
# max    1000.000000  2.155819e+06  1.338622e+06  108893.570000  80430.930000
#
#        Late_Filings  Compliance_Violations        Profit  \
# count   1000.000000            1000.000000  1.000000e+03
# mean       2.029000               1.033000  2.916324e+05
# std        1.415685               0.812756  3.617036e+05
# min        0.000000               0.000000 -7.801314e+05
# 25%        1.000000               0.000000  4.100442e+04
# 50%        2.000000               1.000000  2.856810e+05
# 75%        3.000000               2.000000  5.514364e+05
# max        4.000000               2.000000  1.401163e+06
#
#        Tax_Compliance_Ratio  Audit_Findings  Audit_to_Tax_Ratio
# count           1000.000000     1000.000000              1000.0
# mean               1.077180        4.396000                 0.0
# std                0.617086        2.927414                 0.0
# min                0.240000        0.000000                 0.0
# 25%                0.767500        2.000000                 0.0
# 50%                0.970000        4.000000                 0.0
# 75%                1.210000        7.000000                 0.0
# max               10.190000        9.000000                 0.0

# %% [markdown]
# As shown in the output above, here we get the count of non-null values, mean, standard deviation, lower and upper quartile, minimum and maximum values of each column in the data.

# %%
# checking how the Risk_Label column is balanced
data["Risk_Label"].value_counts()
# Out:
# Risk_Label
# High      736
# Low       152
# Medium    112
# Name: count, dtype: int64

# %%
# checking how the industry column is balanced
data["Industry"].value_counts()
# Out:
# Industry
# Retail           233
# Finance          213
# Tech             188
# Healthcare       188
# Manufacturing    178
# Name: count, dtype: int64

# %% [markdown]
# ## Data prearation

# %% [markdown]
# #### Data Cleaning
# Data cleaning will involve dropping irrelevant columns, checking for duplicates and missing values.

# %%
#Dropping unnecesarry columns
data.drop(columns=["Taxpayer_ID","Audit_to_Tax_Ratio"],inplace=True)
data.head()
# Out:
#       Revenue   Expenses  Tax_Liability  Tax_Paid  Late_Filings  \
# 0  1149014.25  979871.09       39872.33  28921.92             2
# 1   958520.71  884926.74       47832.22  39396.15             1
# 2  1194306.56  711926.07       38113.70  43863.94             4
# 3  1456908.96  570612.64       45380.58  66876.88             4
# 4   929753.99  839644.66       21595.78  53565.53             0
#
#    Compliance_Violations       Industry     Profit  Tax_Compliance_Ratio  \
# 0                      1        Finance  169143.16                  0.73
# 1                      1         Retail   73593.97                  0.82
# 2                      0  Manufacturing  482380.49                  1.15
# 3                      2        Finance  886296.32                  1.47
# 4                      0           Tech   90109.33                  2.48
#
#    Audit_Findings Risk_Label
# 0               0       High
# 1               0     Medium
# 2               3       High
# 3               1       High
# 4               2        Low

# %%
# validating that there are no missing values
data.isna().sum()
# Out:
# Revenue                  0
# Expenses                 0
# Tax_Liability            0
# Tax_Paid                 0
# Late_Filings             0
# Compliance_Violations    0
# Industry                 0
# Profit                   0
# Tax_Compliance_Ratio     0
# Audit_Findings           0
# Risk_Label               0
# dtype: int64

# %%
data["Late_Filings"].unique()
# Out:
# array([2, 1, 4, 0, 3], dtype=int64)

# %%
data["Compliance_Violations"].unique()
# Out:
# array([1, 0, 2], dtype=int64)

# %%
data["Audit_Findings"].unique()
# Out:
# array([0, 3, 1, 2, 8, 4, 9, 6, 5, 7], dtype=int64)

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ### Distribution of numerical features

# %%
# Numerical columns after dropping Taxpayer_ID and Audit_to_Tax_Ratio
numeric_cols = ['Revenue', 'Expenses', 'Tax_Liability', 'Tax_Paid',
                'Profit', 'Tax_Compliance_Ratio']

plt.figure(figsize=(15, 12))
for i, col in enumerate(numeric_cols, 1):
    plt.subplot(2, 3, i)
    sns.histplot(data[col], kde=True, bins=30, color='skyblue')
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Count plot Risk_Label

# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=data, x='Risk_Label', hue='Risk_Label', order=['Low', 'Medium', 'High'], palette='Set2', legend=False)
plt.title('Count of Risk Labels')
plt.xlabel('Risk Label')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# ### Count Plot of Industry

# %%
plt.figure(figsize=(8, 4))
sns.countplot(data=data, x='Industry', hue='Industry', palette='Set3', legend=False)
plt.title('Count of Taxpayers per Industry')
plt.xlabel('Industry')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
#check for duplicates
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# - There is no duplicate data in our dataset.

# %% [markdown]
# # Corellation Analysis

# %% [markdown]
# Visualize the Count of taxpayers under late filling, compliance violation and audit finding

# %%
# create a correlation matrix for the numerical variables
num_data=data.select_dtypes(include="number")

#create a correlation matrix
corr_matrix=num_data.corr()
#make a heatmap out of the correlation matrix
corr_matrix.style.background_gradient(cmap="coolwarm")
# Out:
# <style type="text/css">
# #T_2bfe6_row0_col0, #T_2bfe6_row1_col1, #T_2bfe6_row2_col2, #T_2bfe6_row3_col3, #T_2bfe6_row4_col4, #T_2bfe6_row5_col5, #T_2bfe6_row6_col6, #T_2bfe6_row7_col7, #T_2bfe6_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_2bfe6_row0_col1 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_2bfe6_row0_col2, #T_2bfe6_row3_col2, #T_2bfe6_row6_col2 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_2bfe6_row0_col3, #T_2bfe6_row6_col8, #T_2bfe6_row7_col4 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_2bfe6_row0_col4, #T_2bfe6_row3_col5, #T_2bfe6_row4_col8, #T_2bfe6_row5_col4, #T_2bfe6_row7_col0, #T_2bfe6_row8_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_2bfe6_row0_col5, #T_2bfe6_row0_col8, #T_2bfe6_row2_col4, #T_2bfe6_row5_col8 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_2bfe6_row0_col6 {
#   background-color: #d75445;
#   color: #f1f1f1;
# }
# #T_2bfe6_row0_col7, #T_2bfe6_row5_col2 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_2bfe6_row1_col0, #T_2bfe6_row1_col3, #T_2bfe6_row1_col6, #T_2bfe6_row1_col8, #T_2bfe6_row2_col5, #T_2bfe6_row2_col7, #T_2bfe6_row6_col1, #T_2bfe6_row7_col2, #T_2bfe6_row8_col4, #T_2bfe6_row8_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_2bfe6_row1_col2, #T_2bfe6_row1_col7, #T_2bfe6_row6_col7 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_2bfe6_row1_col4, #T_2bfe6_row3_col0, #T_2bfe6_row4_col5 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_2bfe6_row1_col5, #T_2bfe6_row2_col8 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_2bfe6_row2_col0 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_2bfe6_row2_col1, #T_2bfe6_row7_col6 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_2bfe6_row2_col3, #T_2bfe6_row4_col3 {
#   background-color: #506bda;
#   color: #f1f1f1;
# }
# #T_2bfe6_row2_col6 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_2bfe6_row3_col1 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_2bfe6_row3_col4, #T_2bfe6_row5_col0 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_2bfe6_row3_col6, #T_2bfe6_row7_col3 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_2bfe6_row3_col7 {
#   background-color: #f3c8b2;
#   color: #000000;
# }
# #T_2bfe6_row3_col8 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_2bfe6_row4_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_2bfe6_row4_col1, #T_2bfe6_row5_col1 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_2bfe6_row4_col2 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_2bfe6_row4_col6 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_2bfe6_row4_col7 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_2bfe6_row5_col3 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_2bfe6_row5_col6, #T_2bfe6_row7_col1 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_2bfe6_row5_col7, #T_2bfe6_row8_col7 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_2bfe6_row6_col0 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_2bfe6_row6_col3, #T_2bfe6_row7_col8 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_2bfe6_row6_col4 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_2bfe6_row6_col5 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_2bfe6_row7_col5 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_2bfe6_row8_col1 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_2bfe6_row8_col2 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_2bfe6_row8_col3 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_2bfe6_row8_col6 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# </style>
# <table id="T_2bfe6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2bfe6_level0_col0" class="col_heading level0 col0" >Revenue</th>
#       <th id="T_2bfe6_level0_col1" class="col_heading level0 col1" >Expenses</th>
#       <th id="T_2bfe6_level0_col2" class="col_heading level0 col2" >Tax_Liability</th>
#       <th id="T_2bfe6_level0_col3" class="col_heading level0 col3" >Tax_Paid</th>
#       <th id="T_2bfe6_level0_col4" class="col_heading level0 col4" >Late_Filings</th>
#       <th id="T_2bfe6_level0_col5" class="col_heading level0 col5" >Compliance_Violations</th>
#       <th id="T_2bfe6_level0_col6" class="col_heading level0 col6" >Profit</th>
#       <th id="T_2bfe6_level0_col7" class="col_heading level0 col7" >Tax_Compliance_Ratio</th>
#       <th id="T_2bfe6_level0_col8" class="col_heading level0 col8" >Audit_Findings</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2bfe6_level0_row0" class="row_heading level0 row0" >Revenue</th>
#       <td id="T_2bfe6_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_2bfe6_row0_col1" class="data row0 col1" >-0.040400</td>
#       <td id="T_2bfe6_row0_col2" class="data row0 col2" >0.022129</td>
#       <td id="T_2bfe6_row0_col3" class="data row0 col3" >-0.013321</td>
#       <td id="T_2bfe6_row0_col4" class="data row0 col4" >0.009648</td>
#       <td id="T_2bfe6_row0_col5" class="data row0 col5" >-0.001355</td>
#       <td id="T_2bfe6_row0_col6" class="data row0 col6" >0.834452</td>
#       <td id="T_2bfe6_row0_col7" class="data row0 col7" >-0.019228</td>
#       <td id="T_2bfe6_row0_col8" class="data row0 col8" >-0.016619</td>
#     </tr>
#     <tr>
#       <th id="T_2bfe6_level0_row1" class="row_heading level0 row1" >Expenses</th>
#       <td id="T_2bfe6_row1_col0" class="data row1 col0" >-0.040400</td>
#       <td id="T_2bfe6_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_2bfe6_row1_col2" class="data row1 col2" >-0.011199</td>
#       <td id="T_2bfe6_row1_col3" class="data row1 col3" >-0.054698</td>
#       <td id="T_2bfe6_row1_col4" class="data row1 col4" >0.010454</td>
#       <td id="T_2bfe6_row1_col5" class="data row1 col5" >0.012212</td>
#       <td id="T_2bfe6_row1_col6" class="data row1 col6" >-0.584343</td>
#       <td id="T_2bfe6_row1_col7" class="data row1 col7" >-0.007839</td>
#       <td id="T_2bfe6_row1_col8" class="data row1 col8" >-0.035514</td>
#     </tr>
#     <tr>
#       <th id="T_2bfe6_level0_row2" class="row_heading level0 row2" >Tax_Liability</th>
#       <td id="T_2bfe6_row2_col0" class="data row2 col0" >0.022129</td>
#       <td id="T_2bfe6_row2_col1" class="data row2 col1" >-0.011199</td>
#       <td id="T_2bfe6_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_2bfe6_row2_col3" class="data row2 col3" >0.021586</td>
#       <td id="T_2bfe6_row2_col4" class="data row2 col4" >0.004332</td>
#       <td id="T_2bfe6_row2_col5" class="data row2 col5" >-0.018133</td>
#       <td id="T_2bfe6_row2_col6" class="data row2 col6" >0.024149</td>
#       <td id="T_2bfe6_row2_col7" class="data row2 col7" >-0.674905</td>
#       <td id="T_2bfe6_row2_col8" class="data row2 col8" >-0.004945</td>
#     </tr>
#     <tr>
#       <th id="T_2bfe6_level0_row3" class="row_heading level0 row3" >Tax_Paid</th>
#       <td id="T_2bfe6_row3_col0" class="data row3 col0" >-0.013321</td>
#       <td id="T_2bfe6_row3_col1" class="data row3 col1" >-0.054698</td>
#       <td id="T_2bfe6_row3_col2" class="data row3 col2" >0.021586</td>
#       <td id="T_2bfe6_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_2bfe6_row3_col4" class="data row3 col4" >0.022385</td>
#       <td id="T_2bfe6_row3_col5" class="data row3 col5" >0.003140</td>
#       <td id="T_2bfe6_row3_col6" class="data row3 col6" >0.019349</td>
#       <td id="T_2bfe6_row3_col7" class="data row3 col7" >0.348804</td>
#       <td id="T_2bfe6_row3_col8" class="data row3 col8" >0.055467</td>
#     </tr>
#     <tr>
#       <th id="T_2bfe6_level0_row4" class="row_heading level0 row4" >Late_Filings</th>
#       <td id="T_2bfe6_row4_col0" class="data row4 col0" >0.009648</td>
#       <td id="T_2bfe6_row4_col1" class="data row4 col1" >0.010454</td>
#       <td id="T_2bfe6_row4_col2" class="data row4 col2" >0.004332</td>
#       <td id="T_2bfe6_row4_col3" class="data row4 col3" >0.022385</td>
#       <td id="T_2bfe6_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_2bfe6_row4_col5" class="data row4 col5" >0.007867</td>
#       <td id="T_2bfe6_row4_col6" class="data row4 col6"

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Revenue                1000 non-null   float64
#  1   Expenses               1000 non-null   float64
#  2   Tax_Liability          1000 non-null   float64
#  3   Tax_Paid               1000 non-null   float64
#  4   Late_Filings           1000 non-null   int64
#  5   Compliance_Violations  1000 non-null   int64
#  6   Industry               1000 non-null   object
#  7   Profit                 1000 non-null   float64
#  8   Tax_Compliance_Ratio   1000 non-null   float64
#  9   Audit_Findings         1000 non-null   int64
#  10  Risk_Label             1000 non-null   object
# dtypes: float64(6), int64(3), object(2)
# memory usage: 86.1+ KB

# %%
# Encoding our risk label column using label encoder 

risk_encoder = LabelEncoder()

data['Risk_Label'] = risk_encoder.fit_transform(data['Risk_Label'])

data.head(10)
# Out:
#       Revenue   Expenses  Tax_Liability  Tax_Paid  Late_Filings  \
# 0  1149014.25  979871.09       39872.33  28921.92             2
# 1   958520.71  884926.74       47832.22  39396.15             1
# 2  1194306.56  711926.07       38113.70  43863.94             4
# 3  1456908.96  570612.64       45380.58  66876.88             4
# 4   929753.99  839644.66       21595.78  53565.53             0
# 5   929758.91  778697.08       53199.41  34645.18             0
# 6  1473763.84  879038.64       50018.08  52860.36             2
# 7  1230230.42  827034.36       37743.67  32526.96             1
# 8   859157.68  909910.54       59888.69  58826.91             3
# 9  1162768.01  592952.96       64063.55  43288.75             0
#
#    Compliance_Violations       Industry     Profit  Tax_Compliance_Ratio  \
# 0                      1        Finance  169143.16                  0.73
# 1                      1         Retail   73593.97                  0.82
# 2                      0  Manufacturing  482380.49                  1.15
# 3                      2        Finance  886296.32                  1.47
# 4                      0           Tech   90109.33                  2.48
# 5                      2  Manufacturing  151061.83                  0.65
# 6                      0     Healthcare  594725.20                  1.06
# 7                      2        Finance  403196.06                  0.86
# 8                      0     Healthcare  -50752.86                  0.98
# 9                      2     Healthcare  569815.05                  0.68
#
#    Audit_Findings  Risk_Label
# 0               0           0
# 1               0           2
# 2               3           0
# 3               1           0
# 4               2           1
# 5               8           0
# 6               1           2
# 7               3           0
# 8               0           0
# 9               1           0

# %%
# Convert the Industry column to use label encoding 

data['Industry'] = risk_encoder.fit_transform(data['Industry'])

data.head(10)
# Out:
#       Revenue   Expenses  Tax_Liability  Tax_Paid  Late_Filings  \
# 0  1149014.25  979871.09       39872.33  28921.92             2
# 1   958520.71  884926.74       47832.22  39396.15             1
# 2  1194306.56  711926.07       38113.70  43863.94             4
# 3  1456908.96  570612.64       45380.58  66876.88             4
# 4   929753.99  839644.66       21595.78  53565.53             0
# 5   929758.91  778697.08       53199.41  34645.18             0
# 6  1473763.84  879038.64       50018.08  52860.36             2
# 7  1230230.42  827034.36       37743.67  32526.96             1
# 8   859157.68  909910.54       59888.69  58826.91             3
# 9  1162768.01  592952.96       64063.55  43288.75             0
#
#    Compliance_Violations  Industry     Profit  Tax_Compliance_Ratio  \
# 0                      1         0  169143.16                  0.73
# 1                      1         3   73593.97                  0.82
# 2                      0         2  482380.49                  1.15
# 3                      2         0  886296.32                  1.47
# 4                      0         4   90109.33                  2.48
# 5                      2         2  151061.83                  0.65
# 6                      0         1  594725.20                  1.06
# 7                      2         0  403196.06                  0.86
# 8                      0         1  -50752.86                  0.98
# 9                      2         1  569815.05                  0.68
#
#    Audit_Findings  Risk_Label
# 0               0           0
# 1               0           2
# 2               3           0
# 3               1           0
# 4               2           1
# 5               8           0
# 6               1           2
# 7               3           0
# 8               0           0
# 9               1           0

# %%
# One hot encoding for the Risk Label and Industry 

industry_data = pd.DataFrame(imported_data['Industry'], columns=['Industry'])

one_hot_encode = OneHotEncoder()

ohe_array = one_hot_encode.fit_transform(industry_data[['Industry']]).toarray()

col_names= one_hot_encode.get_feature_names_out(['Industry'])

ohe_industry_data= pd.DataFrame(data=ohe_array, columns=col_names )

industry_data = pd.concat([industry_data, ohe_industry_data],axis=1)

industry_data.sample(10)
# Out:
#           Industry  Industry_Finance  Industry_Healthcare  \
# 581           Tech               0.0                  0.0
# 311           Tech               0.0                  0.0
# 190  Manufacturing               0.0                  0.0
# 120        Finance               1.0                  0.0
# 569  Manufacturing               0.0                  0.0
# 848           Tech               0.0                  0.0
# 886     Healthcare               0.0                  1.0
# 449  Manufacturing               0.0                  0.0
# 104  Manufacturing               0.0                  0.0
# 595  Manufacturing               0.0                  0.0
#
#      Industry_Manufacturing  Industry_Retail  Industry_Tech
# 581                     0.0              0.0            1.0
# 311                     0.0              0.0            1.0
# 190                     1.0              0.0            0.0
# 120                     0.0              0.0            0.0
# 569                     1.0              0.0            0.0
# 848                     0.0              0.0            1.0
# 886                     0.0              0.0            0.0
# 449                     1.0              0.0            0.0
# 104                     1.0              0.0            0.0
# 595                     1.0              0.0            0.0

# %%
# One hot encoding for the Risk Label and Industry 
Risk_Label_data = pd.DataFrame(imported_data['Risk_Label'], columns=['Risk_Label'])

one_hot_encode = OneHotEncoder()

ohe_array = one_hot_encode.fit_transform(Risk_Label_data[['Risk_Label']]).toarray()

col_names= one_hot_encode.get_feature_names_out(['Risk_Label'])

ohe_Risk_Label_data= pd.DataFrame(data=ohe_array, columns=col_names )

Risk_Label_data = pd.concat([Risk_Label_data, ohe_Risk_Label_data],axis=1)

Risk_Label_data.sample(10)
# Out:
#     Risk_Label  Risk_Label_High  Risk_Label_Low  Risk_Label_Medium
# 720       High              1.0             0.0                0.0
# 538       High              1.0             0.0                0.0
# 668       High              1.0             0.0                0.0
# 431       High              1.0             0.0                0.0
# 819       High              1.0             0.0                0.0
# 135        Low              0.0             1.0                0.0
# 178       High              1.0             0.0                0.0
# 582       High              1.0             0.0                0.0
# 477       High              1.0             0.0                0.0
# 911        Low              0.0             1.0                0.0

# %% [markdown]
# # Standardization
